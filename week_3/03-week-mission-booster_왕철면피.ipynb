# %% [markdown]
# ## 3주차 미션 소개 -  피처 엔지니어링(Feature Engineering)
#
# * 피처 엔지니어링(Feature Engineering)은 머신러닝 모델을 훈련시키기 위해 입력 데이터로 사용되는 피처(또는 변수)들을 가공하거나 새로운 피처를 만들어내는 과정을 말합니다. 피처 엔지니어링은 머신러닝 성능을 향상시키고 모델의 일반화 성능을 향상시키는 데 핵심적인 역할을 합니다. 현실 세계의 데이터는 종종 불완전하고 노이즈가 많습니다. 결측값, 이상치, 오류 등이 있을 수 있습니다. 종속 변수와의 관계를 강화하고 모델이 더 나은 예측을 할 수 있도록 도와줍니다. 예를 들어, 특정 도메인 지식을 활용하여 새로운 피처를 생성하거나 기존 피처를 변형시켜 모델이 패턴을 더 잘 파악하도록 할 수 있습니다. 불필요한 피처를 제거하거나 피처를 효과적으로 변형함으로써 모델의 계산 효율성을 높일 수 있습니다. 이는 모델을 더 빠르게 훈련시키고 실행시킬 수 있습니다.
#
# * 미션 데이터셋 소개
#
#     * 해당 Kaggle 데이터셋( https://www.kaggle.com/blastchar/telco-customer-churn )은 통신사 고객 이탈(Churn)에 대한 정보를 담고 있습니다. IBM에서 제공한 이 데이터셋은 고객 유지에 필요한 행동을 예측하는 데 사용될 수 있으며, 고객 데이터를 분석하여 고객 유지 프로그램을 개발하는 데 도움이 됩니다.
#     * 해당 데이터셋은 다음의 정보로 구성되어 있습니다.
#         * 고객 인구 통계 정보(Demographic info): 고객의 성별, 연령대, 배우자 및 부양 가족의 유무(Gender, SeniorCitizen, Partner, Dependents) 등에 관한 정보가 포함되어 있습니다.
#         * 고객 이탈(Churn) 정보: 서비스를 중단 여부에 대한 정보가 포함되어 있습니다.
#         * 서비스 가입 정보(Services subscribed): 고객들이 가입한 서비스들, 예를 들어 전화, 다중 라인, 인터넷, 온라인 보안, 온라인 백업, 장치 보호, 기술 지원, 스트리밍 TV 및 영화( honeService, MultipleLine, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies) 등에 대한 정보가 있습니다.
#         * 고객 계정 정보(Customer account info): 고객이 얼마나 오래 서비스를 이용했는지, 계약 유형, 결제 방법, 무페이퍼 청구 여부, 월별 요금, 총 요금 (CustomerID, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Tenure)등의 정보가 담겨 있습니다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 미션 수행을 위해 데이터셋을 로드합니다.
df = pd.read_csv("https://bit.ly/telco-csv", index_col="customerID")
df.shape
# Out:
# (7043, 20)

# %%
df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
#
#             MonthlyCharges TotalCharges Churn
# customerID
# 7590-VHVEG           29.85        29.85    No
# 5575-GNVDE           56.95       1889.5    No
# 3668-QPYBK           53.85       108.15   Yes
# 7795-CFOCW           42.30      1840.75    No
# 9237-HQITU           70.70       151.65   Yes

# %%
# TotalCharges 가 수치 타입이 아니기 때문에 수치 연산을 위해 숫자 형태로 변경합니다.
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df = df.dropna()

# %% [markdown]
# ## 미션 1) - 수치형 변수를 범주형 변수로 만들기
#
# * 월별 지불 금액을 그룹화하여 지불 금액 구간별 경향성을 분석할 수 있습니다. 이러한 수치형 데이터의 범주화는 수치형 데이터에 이상치가 있을 경우, 이를 구간화함으로써 이상치의 영향을 줄일 수 있습니다. 범주화된 데이터는 일반적으로 이해하기 쉽습니다. 그리고 모델이 특정 수치에 과도하게 적합되는 것을 방지할 수 있습니다. 수치형 데이터를 구간으로 나눔으로써 모델이 데이터의 일반적인 패턴을 학습하는 데 집중하도록 할 수 있습니다. 범주화된 데이터는 시각화 및 보고서 작성 시 직관적이고 명확한 정보 전달이 가능합니다. 데이터의 분포, 추세 등을 파악하기에 용이합니다. 데이터의 분포가 불균일할 때, 구간화를 통해 각 범주 내 데이터의 분포를 보다 균일하게 만들 수 있습니다. 위와 같은 이유로 수치형 변수를 범주화 하는 미션을 진행해 보겠습니다.
#
# * 수치형 변수를 범주형 변수로 변환합니다.
# * MonthlyCharges 를 4개의 구간으로 나눕니다. 구간을 나누는 기준은 시각화 내용을 바탕으로 정하며 기준에 대한 정답이 있지는 않습니다. 구간을 정한 기준을 설명으로 작성하고 구간을 나누는 코드를 작성해 주세요.
#
# * 다음과 같이 원본과 구간을 나눈 데이터를 비교해 주세요. 기준이 정해져 있지 않으며 정답이 없으니 자율적으로 나눠 보세요.
#
# | customerID   |   MonthlyCharges | monthlycharges_group   |
# |:-------------|-----------------:|:-----------------------|
# | 7590-VHVEG   |            29.85 | 0-30                   |
# | 5575-GNVDE   |            56.95 | 30-70                  |
# | 3668-QPYBK   |            53.85 | 30-70                  |
# | 7795-CFOCW   |            42.3  | 30-70                  |
# | 9237-HQITU   |            70.7  | 70-99                  |
#
# <table>
#     <tr>
#         <td><img src="https://i.imgur.com/Tiub25Z.png" width="300"></td>
#         <td><img src="https://i.imgur.com/7iGsGPB.png" width="300"></td>
#     </tr>
# </table>

# %%
# 여기에 코드를 입력해 주세요.
# 데이터를 범위 기준으로 4등분(pd.cut)
# 각 구간의 범위가 같다.
df["MCGroup_ab"]=pd.cut(df['MonthlyCharges'], bins=4)
sns.countplot(data=df, x='MCGroup_ab', hue="Churn")
# Out:
# <Axes: xlabel='MCGroup_ab', ylabel='count'>

# %%
# 데이터를 데이터 수 기준으로 4등분
# 각 구간의 데이터 수가 같다.
df["MCGroup_rl"]=pd.qcut(df['MonthlyCharges'], q=4)
sns.countplot(data=df, x='MCGroup_rl', hue="Churn")
# Out:
# <Axes: xlabel='MCGroup_rl', ylabel='count'>

# %%
# 여기에 구간화 전의 수치 변수에 대한 히스토그램과 구간화 이후 범주로 변환해준 변수에 대한 countplot을 시각화 해주세요.
fig, axes=plt.subplots(1, 3, figsize=(18, 3))

plot_col=['MonthlyCharges', "MCGroup_ab", "MCGroup_rl"]
for i, col in enumerate(plot_col):
  if col=="MonthlyCharges":
    sns.histplot(data=df, x=col, hue="Churn", ax=axes[i])
  else:
    sns.countplot(data=df, x=col, hue='Churn', ax=axes[i])

# %% [markdown]
# ## 미션 2) - One-Hot-Encoding 하기
#
# * One-Hot Encoding은 범주형 데이터를 머신러닝 모델이 이해할 수 있는 형태로 변환하는 기술 중 하나입니다. One-Hot Encoding을 사용하면 각 범주 간의 거리가 동일하게 유지됩니다. 즉, 범주 간의 유사성을 측정할 때 각 범주가 동일한 거리로 취급되므로 모델이 범주 간의 관계를 더 정확하게 학습할 수 있습니다. One-Hot Encoding은 범주의 수에 따라 적절한 차원을 생성하므로 데이터가 새로운 범주로 확장되거나 변할 때 모델이 쉽게 일반화될 수 있습니다. 각 범주가 독립된 차원으로 표현되므로, 모델의 예측이나 특성 중요도를 해석할 때 각 범주에 대한 기여를 명확하게 파악할 수 있습니다. 라벨 인코딩과 같은 다른 방법들이 범주 간의 임의의 순서를 생성할 수 있는 반면, One-hot encoding은 이러한 문제를 방지하고 모델이 데이터를 오해하는 것을 막습니다. 하지만, One-hot encoding은 범주의 수가 매우 많을 때 차원의 저주(curse of dimensionality)를 초래하거나, 데이터가 희소해질 수 있으므로 적용 시 이러한 점을 고려해야 합니다. 다음의 예시처럼 데이터를 One-Hot-Encoding 해주세요.
#
# <img src="https://i.imgur.com/9Njm4aN.png">
#
# | customerID   |   SeniorCitizen |   tenure |   TotalCharges |   gender_Female |   gender_Male |   Partner_No |   Partner_Yes |   Dependents_No |   Dependents_Yes |   PhoneService_No |
# |:-------------|----------------:|---------:|---------------:|----------------:|--------------:|-------------:|--------------:|----------------:|-----------------:|------------------:|
# | 7590-VHVEG   |               0 |        1 |          29.85 |               1 |             0 |            0 |             1 |               1 |                0 |                 1 |
# | 5575-GNVDE   |               0 |       34 |        1889.5  |               0 |             1 |            1 |             0 |               1 |                0 |                 0 |
# | 3668-QPYBK   |               0 |        2 |         108.15 |               0 |             1 |            1 |             0 |               1 |                0 |                 0 |
# | 7795-CFOCW   |               0 |       45 |        1840.75 |               0 |             1 |            1 |             0 |               1 |                0 |                 1 |
# | 9237-HQITU   |               0 |        2 |         151.65 |               1 |             0 |            1 |             0 |               1 |                0 |                 0 |

# %%
# 여기에 one-hot-encoding 을 구현해 주세요.
# 지난 과제 중 Churn에 많은 영향력을 미친다고 판단된 요소 중 하나의 OnlineSecurity, OnlineBackup, DeviceProtection을 one-hot encoding으로 생성
df_encoded=pd.get_dummies(df, columns=['OnlineSecurity', 'OnlineBackup', 'DeviceProtection'])
df_encoded
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService TechSupport StreamingTV  ...  \
# customerID                                                            ...
# 7590-VHVEG  No phone service             DSL          No          No  ...
# 5575-GNVDE                No             DSL          No          No  ...
# 3668-QPYBK                No             DSL          No          No  ...
# 7795-CFOCW  No phone service             DSL         Yes          No  ...
# 9237-HQITU                No     Fiber optic          No          No  ...
# ...                      ...             ...         ...         ...  ...
# 6840-RESVB               Yes             DSL         Yes         Yes  ...
# 2234-XADUH               Yes     Fiber optic          No         Yes  ...
# 4801-JZAZL  No phone service             DSL          No          No  ...
# 8361-LTMKD               Yes     Fiber optic          No          No  ...
# 3186-AJIEK                No     Fiber optic         Yes         Yes  ...
#
#                   MCGroup_rl OnlineSecurity_No  \
# customerID
# 7590-VHVEG  (18.249, 35.588]                 1
# 5575-GNVDE   (35.588, 70.35]                 0
# 3668-QPYBK   (35.588, 70.35]                 0
# 7795-CFOCW   (35.588, 70.35]                 0
# 9237-HQITU   (70.35, 89.862]                 1
# ...                      ...               ...
# 6840-RESVB   (70.35, 89.862]                 0
# 2234-XADUH  (89.862, 118.75]                 1
# 4801-JZAZL  (18.249, 35.588]                 0
# 8361-LTMKD   (70.35, 89.862]                 1
# 3186-AJIEK  (89.862, 118.75]                 0
#
#            OnlineSecurity_No internet service OnlineSecurity_Yes  \
# customerID
# 7590-VHVEG                                  0                  0
# 5575-GNVDE                                  0                  1
# 3668-QPYBK                                  0                  1
# 7795-CFOCW                                  0                  1
# 9237-HQITU                                  0                  0
# ...                                       ...                ...
# 6840-RESVB                                  0                  1
# 2234-XADUH                                  0                  0
# 4801-JZAZL                                  0                  1
# 8361-LTMKD                                  0                  0
# 3186-AJIEK                                  0                  1
#
#             OnlineBackup_No  OnlineBackup_No internet service  \
# customerID
# 7590-VHVEG                0                                 0
# 5575-GNVDE                1                                 0
# 3668-QPYBK                0                                 0
# 7795-CFOCW                1                                 0
# 9237-HQITU                1                                 0
# ...                     ...                               ...
# 6840-RESVB                1                                 0
# 2234-XADUH                0                                 0
# 4801-JZAZL                1                                 0
# 8361-LTMKD                1                                 0
# 3186-AJIEK                1                                 0
#
#            OnlineBackup_Yes DeviceProtection_No  \
# customerID
# 7590-VHVEG                1                   1
# 5575-GNVDE                0                   0
# 3668-QPYBK                1                   1
# 7795-CFOCW                0                   0
# 9237-HQITU                0                   1
# ...                     ...                 ...
# 6840-RESVB                0                   0
# 2234-XADUH                1                   0
# 4801-JZAZL                0                   1
# 8361-LTMKD                0                   1
# 3186-AJIEK                0                   0
#
#            DeviceProtection_No internet service  DeviceProtection_Yes
# customerID
# 7590-VHVEG                                    0                     0
# 5575-GNVDE                                    0                     1
# 3668-QPYBK                                    0                     0
# 7795-CFOCW                                    0                     1
# 9237-HQITU                                    0                     0
# ...                                         ...                   ...
# 6840-RESVB                                    0                     1
# 2234-XADUH                                    0                     1
# 4801-JZAZL                                    0                     0
# 8361-LTMKD                                    0                     0
# 3186-AJIEK                                    0                     1
#
# [7032 rows x 28 columns]

# %% [markdown]
# ## 미션 3) - 여러 피처 엔지니어링 기법을 적용하고 통신사 고객 이탈여부에 대한 모델의 성능을 Accuracy로 평가해 주세요.
#
# * 이 미션은 데이터 전처리와 피처 엔지니어링의 중요성을 이해하고, 실제 비즈니스 문제에 적용할 수 있는 머신러닝 모델을 개발하는 데 중점을 둡니다. 통신사 고객 데이터를 활용하여 고객의 이탈 여부를 예측하는 머신러닝 모델을 개발하고, 여러 피처 엔지니어링 기법을 적용하여 모델의 정확도(Accuracy)를 높여보세요. 고객 이탈 여부 예측은 통신사에 있어 중요한 비즈니스 문제로, 고객 유지 전략 수립에 큰 영향을 미칩니다.
#
# * 피처엔지니어링을 진행하고 모델의 성능을 평가합니다.
# * 모델은 트리계열 모델 외 다른 모델을 사용해도 됩니다.

# %% [markdown]
# ## feature 골라내기
# 몇몇 높은 성능의 모델이 존재한다고 할 때, 가장 먼저 고려할 점은 feature engineering이 될 것이다.
# 개중 가장 먼저 할 일은 이탈 여부에 영향을 미치지 않을 것으로 보이는 feature를 선별하는 것이다.
# 미션 2의 분석에서 각종 feature의 각 변수별 이탈률이 차이나지 않는 gender를 사용하지 않을 것이다.
# 그 다음으로는 범주형 feature 중 string 형식의 값들을 변환시켜야 한다. 하나의 feature에 2종의 값만 존재할 경우 0과 1로 변환할 것이며, 3종 이상이면 one-hot encoding을 수행할 것이다.

# %%
import pprint
# feature확인, object 타입인 column 확인
string_columns=df.select_dtypes(include=['object']).columns.tolist()
string_columns.remove('gender')
pprint.pprint(string_columns)
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
# 각 object column(feature)가 가지는 값의 수
# 2개는 0과 1로 표현(partner, dependents, phoneservice, paperlessbilling, Churn)
# 3개 이상은 one-hot encoding 예정, (multiplelines, internetservice, onlinesecurity, onlinebackup, deviceprotection, techsupport, streamingtv, streamingmovies, contract, paymentmethod)
# feature가 많아진다는 문제가 있지만, 한번 해보기로 결정
nun_ser=df[string_columns].nunique()
bi_list=nun_ser[nun_ser <= 2].index.to_list()
mul_list=nun_ser[nun_ser > 2].index.to_list()
print(bi_list)
print(mul_list)
# Out:
# ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']
# ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod']

# %%
df_conv=df.copy()
df_conv.drop('gender', axis=1, inplace=True)

# %%
df_conv[bi_list]
# Out:
#            Partner Dependents PhoneService PaperlessBilling Churn
# customerID
# 7590-VHVEG     Yes         No           No              Yes    No
# 5575-GNVDE      No         No          Yes               No    No
# 3668-QPYBK      No         No          Yes              Yes   Yes
# 7795-CFOCW      No         No           No               No    No
# 9237-HQITU      No         No          Yes              Yes   Yes
# ...            ...        ...          ...              ...   ...
# 6840-RESVB     Yes        Yes          Yes              Yes    No
# 2234-XADUH     Yes        Yes          Yes              Yes    No
# 4801-JZAZL     Yes        Yes           No              Yes    No
# 8361-LTMKD     Yes         No          Yes              Yes   Yes
# 3186-AJIEK      No         No          Yes              Yes    No
#
# [7032 rows x 5 columns]

# %%
# 값이 2종인 변수들은 모두 Yes/NO로 이루어져 있음. No=False, Yes=True로 변환
yesno_mapping={'No': False, 'Yes': True}
df_conv[bi_list]=df_conv[bi_list].replace(yesno_mapping)
df_conv[bi_list]
# Out:
#             Partner  Dependents  PhoneService  PaperlessBilling  Churn
# customerID
# 7590-VHVEG     True       False         False              True  False
# 5575-GNVDE    False       False          True             False  False
# 3668-QPYBK    False       False          True              True   True
# 7795-CFOCW    False       False         False             False  False
# 9237-HQITU    False       False          True              True   True
# ...             ...         ...           ...               ...    ...
# 6840-RESVB     True        True          True              True  False
# 2234-XADUH     True        True          True              True  False
# 4801-JZAZL     True        True         False              True  False
# 8361-LTMKD     True       False          True              True   True
# 3186-AJIEK    False       False          True              True  False
#
# [7032 rows x 5 columns]

# %%
# one-hot encoding 후 그 대상 feature는 제거
df_conv=pd.get_dummies(df_conv, columns=mul_list)
df_conv
# Out:
#             SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG              0     True       False       1         False
# 5575-GNVDE              0    False       False      34          True
# 3668-QPYBK              0    False       False       2          True
# 7795-CFOCW              0    False       False      45         False
# 9237-HQITU              0    False       False       2          True
# ...                   ...      ...         ...     ...           ...
# 6840-RESVB              0     True        True      24          True
# 2234-XADUH              0     True        True      72          True
# 4801-JZAZL              0     True        True      11         False
# 8361-LTMKD              1     True       False       4          True
# 3186-AJIEK              0    False       False      66          True
#
#             PaperlessBilling  MonthlyCharges  TotalCharges  Churn  \
# customerID
# 7590-VHVEG              True           29.85         29.85  False
# 5575-GNVDE             False           56.95       1889.50  False
# 3668-QPYBK              True           53.85        108.15   True
# 7795-CFOCW             False           42.30       1840.75  False
# 9237-HQITU              True           70.70        151.65   True
# ...                      ...             ...           ...    ...
# 6840-RESVB              True           84.80       1990.50  False
# 2234-XADUH              True          103.20       7362.90  False
# 4801-JZAZL              True           29.60        346.45  False
# 8361-LTMKD              True           74.40        306.60   True
# 3186-AJIEK              True          105.65       6844.50  False
#
#                   MCGroup_ab  ... StreamingMovies_No  \
# customerID                    ...
# 7590-VHVEG   (18.15, 43.375]  ...                  1
# 5575-GNVDE    (43.375, 68.5]  ...                  1
# 3668-QPYBK    (43.375, 68.5]  ...                  1
# 7795-CFOCW   (18.15, 43.375]  ...                  1
# 9237-HQITU    (68.5, 93.625]  ...                  1
# ...                      ...  ...                ...
# 6840-RESVB    (68.5, 93.625]  ...                  0
# 2234-XADUH  (93.625, 118.75]  ...                  0
# 4801-JZAZL   (18.15, 43.375]  ...                  1
# 8361-LTMKD    (68.5, 93.625]  ...                  1
# 3186-AJIEK  (93.625, 118.75]  ...                  0
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                    0                    0
# 5575-GNVDE                                    0                    0
# 3668-QPYBK                                    0                    0
# 7795-CFOCW                                    0                    0
# 9237-HQITU                                    0                    0
# ...                                         ...                  ...
# 6840-RESVB                                    0                    1
# 2234-XADUH                                    0                    1
# 4801-JZAZL                                    0                    0
# 8361-LTMKD                                    0                    0
# 3186-AJIEK                                    0                    1
#
#             Contract_Month-to-month  Contract_One year  Contract_Two year  \
# customerID
# 7590-VHVEG                        1                  0                  0
# 5575-GNVDE                        0                  1                  0
# 3668-QPYBK                        1                  0                  0
# 7795-CFOCW                        0                  1                  0
# 9237-HQITU                        1                  0                  0
# ...                             ...                ...                ...
# 6840-RESVB                        0                  1                  0
# 2234-XADUH                        0                  1                  0
# 4801-JZAZL                        1                  0                  0
# 8361-LTMKD                        1                  0                  0
# 3186-AJIEK                        0                  0                  1
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                        0
# 5575-GNVDE                                        0
# 3668-QPYBK                                        0
# 7795-CFOCW                                        1
# 9237-HQITU                                        0
# ...                                             ...
# 6840-RESVB                                        0
# 2234-XADUH                                        0
# 4801-JZAZL                                        0
# 8361-LTMKD                                        0
# 3186-AJIEK                                        1
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                      0
# 5575-GNVDE                                      0
# 3668-QPYBK                                      0
# 7795-CFOCW                                      0
# 9237-HQITU                                      0
# ...                                           ...
# 6840-RESVB                                      0
# 2234-XADUH                                      1
# 4801-JZAZL                                      0
# 8361-LTMKD                                      0
# 3186-AJIEK                                      0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                               1                           0
# 5575-GNVDE                               0                           1
# 3668-QPYBK                               0                           1
# 7795-CFOCW                               0                           0
# 9237-HQITU                               1                           0
# ...                                    ...                         ...
# 6840-RESVB                               0                           1
# 2234-XADUH                               0                           0
# 4801-JZAZL                               1                           0
# 8361-LTMKD                               0                           1
# 3186-AJIEK                               0                           0
#
# [7032 rows x 42 columns]

# %%
# monthlycharge 계열 데이터는 , MCGroup_rl을 제외하고는 제거
# df_conv=df_conv.drop(['MonthlyCharges', 'MCGroup_ab'], axis=1)
df_conv.columns
# Out:
# Index(['SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'MCGroup_ab', 'MCGroup_rl', 'MultipleLines_No',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
# totalcharge도 범주화 및 제거
df_conv["TCGroup_rl"]=pd.qcut(df['TotalCharges'], q=4)
# df_conv=df_conv.drop(['TotalCharges'], axis=1)
df_conv.columns
# Out:
# Index(['SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'MCGroup_ab', 'MCGroup_rl', 'MultipleLines_No',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'TCGroup_rl'],
#       dtype='object')

# %%
# 어떤 feature를 사용할지 리스트화
# 분석 대상에 string이 들어가 있으면 안되기 때문에, Yes와 No, 두가지 선택지의 경우 True-False로 표시하고,
# 선택지가 3개 이상인 경우 one-hot encoding을 사용하는 편이 좋을 것 같다.
feature_list=df_conv.columns.tolist()
feature_list.remove("Churn")
# feature_list.remove("TotalCharges")
# feature_list.remove('MonthlyCharges')
feature_list.remove('MCGroup_rl')
feature_list.remove('MCGroup_ab')
feature_list.remove('TCGroup_rl')
feature_list
# Out:
# ['SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'PaperlessBilling',
#  'MonthlyCharges',
#  'TotalCharges',
#  'MultipleLines_No',
#  'MultipleLines_No phone service',
#  'MultipleLines_Yes',
#  'InternetService_DSL',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_No',
#  'OnlineSecurity_No internet service',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No',
#  'OnlineBackup_No internet service',
#  'OnlineBackup_Yes',
#  'DeviceProtection_No',
#  'DeviceProtection_No internet service',
#  'DeviceProtection_Yes',
#  'TechSupport_No',
#  'TechSupport_No internet service',
#  'TechSupport_Yes',
#  'StreamingTV_No',
#  'StreamingTV_No internet service',
#  'StreamingTV_Yes',
#  'StreamingMovies_No',
#  'StreamingMovies_No internet service',
#  'StreamingMovies_Yes',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaymentMethod_Bank transfer (automatic)',
#  'PaymentMethod_Credit card (automatic)',
#  'PaymentMethod_Electronic check',
#  'PaymentMethod_Mailed check']

# %%
label_name="Churn"

# %%
X= df_conv[feature_list]
y= df_conv[label_name]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# 여기에 모델을 구현해 주세요.
from sklearn.tree import DecisionTreeClassifier

model=DecisionTreeClassifier()

# %%
# 위에서 만든 모델로 학습과 예측을 진행해 주세요.
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 학습 결과와 원래 정답과의 Accuracy(정확도)를 구해주세요.
y_predict=model.predict(X_test)
y_predict[:5]
# Out:
# array([False,  True, False, False, False])

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=feature_list)
# Out:
# [Text(0.3702860570591334, 0.98, 'Contract_Month-to-month <= 0.5\ngini = 0.39\nsamples = 5625\nvalue = [4130, 1495]'),
#  Text(0.1497040860002634, 0.94, 'MonthlyCharges <= 93.675\ngini = 0.122\nsamples = 2540\nvalue = [2374, 166]'),
#  Text(0.09057684709600948, 0.9, 'Contract_Two year <= 0.5\ngini = 0.072\nsamples = 1906\nvalue = [1835, 71]'),
#  Text(0.05109969708942447, 0.86, 'StreamingMovies_Yes <= 0.5\ngini = 0.123\nsamples = 865\nvalue = [808, 57]'),
#  Text(0.034505465560384564, 0.82, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.082\nsamples = 631\nvalue = [604, 27]'),
#  Text(0.02028183853549322, 0.78, 'OnlineSecurity_No <= 0.5\ngini = 0.055\nsamples = 528\nvalue = [513, 15]'),
#  Text(0.010799420518898985, 0.74, 'tenure <= 25.5\ngini = 0.038\nsamples = 417\nvalue = [409, 8]'),
#  Text(0.0068484130119847225, 0.7, 'TotalCharges <= 1618.0\ngini = 0.069\nsamples = 167\nvalue = [161, 6]'),
#  Text(0.005794811010140919, 0.66, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.047\nsamples = 165\nvalue = [161, 4]'),
#  Text(0.0031608060055314103, 0.62, 'TotalCharges <= 147.5\ngini = 0.015\nsamples = 131\nvalue = [130, 1]'),
#  Text(0.002107204003687607, 0.58, 'TotalCharges <= 140.875\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.0010536020018438036, 0.54, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.0031608060055314103, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.004214408007375214, 0.58, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.008428816014750429, 0.62, 'MultipleLines_Yes <= 0.5\ngini = 0.161\nsamples = 34\nvalue = [31, 3]'),
#  Text(0.006321612011062821, 0.58, 'Dependents <= 0.5\ngini = 0.121\nsamples = 31\nvalue = [29, 2]'),
#  Text(0.005268010009219017, 0.54, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.007375214012906624, 0.54, 'TotalCharges <= 393.225\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.006321612011062821, 0.5, 'MonthlyCharges <= 19.85\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.005268010009219017, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.007375214012906624, 0.46, 'TotalCharges <= 368.375\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.006321612011062821, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.008428816014750429, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008428816014750429, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.010536020018438034, 0.58, 'TotalCharges <= 640.8\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.009482418016594232, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.011589622020281838, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.007902015013828527, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.014750428025813249, 0.7, 'tenure <= 52.5\ngini = 0.016\nsamples = 250\nvalue = [248, 2]'),
#  Text(0.013696826023969445, 0.66, 'gini = 0.0\nsamples = 165\nvalue = [165, 0]'),
#  Text(0.015804030027657054, 0.66, 'TotalCharges <= 1024.075\ngini = 0.046\nsamples = 85\nvalue = [83, 2]'),
#  Text(0.013696826023969445, 0.62, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.012643224022125641, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014750428025813249, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01791123403134466, 0.62, 'TechSupport_No <= 0.5\ngini = 0.024\nsamples = 82\nvalue = [81, 1]'),
#  Text(0.016857632029500857, 0.58, 'gini = 0.0\nsamples = 60\nvalue = [60, 0]'),
#  Text(0.018964836033188465, 0.58, 'tenure <= 58.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.01791123403134466, 0.54, 'MultipleLines_No <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.016857632029500857, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.018964836033188465, 0.5, 'MonthlyCharges <= 56.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01791123403134466, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.020018438035032268, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.020018438035032268, 0.54, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.029764256552087448, 0.74, 'MonthlyCharges <= 24.225\ngini = 0.118\nsamples = 111\nvalue = [104, 7]'),
#  Text(0.028710654550243644, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03081785855393125, 0.7, 'TotalCharges <= 1618.75\ngini = 0.103\nsamples = 110\nvalue = [104, 6]'),
#  Text(0.027920453048860792, 0.66, 'TotalCharges <= 1578.85\ngini = 0.21\nsamples = 42\nvalue = [37, 5]'),
#  Text(0.026866851047016988, 0.62, 'MultipleLines_Yes <= 0.5\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(0.02423284604240748, 0.58, 'tenure <= 41.5\ngini = 0.108\nsamples = 35\nvalue = [33, 2]'),
#  Text(0.022125642038719872, 0.54, 'MonthlyCharges <= 54.95\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.02107204003687607, 0.5, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.023179244040563676, 0.5, 'MonthlyCharges <= 55.175\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.022125642038719872, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02423284604240748, 0.46, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.026340050046095086, 0.54, 'PaymentMethod_Mailed check <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.025286448044251283, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02739365204793889, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.029500856051626497, 0.58, 'TechSupport_No <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.028447254049782694, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0305544580534703, 0.54, 'tenure <= 15.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.029500856051626497, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03160806005531411, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.028974055050704595, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.033715264059001715, 0.66, 'SeniorCitizen <= 0.5\ngini = 0.029\nsamples = 68\nvalue = [67, 1]'),
#  Text(0.03266166205715791, 0.62, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.03476886606084552, 0.62, 'tenure <= 42.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.033715264059001715, 0.58, 'OnlineBackup_Yes <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03266166205715791, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03476886606084552, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03582246806268932, 0.58, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.04872909258527591, 0.78, 'TotalCharges <= 5353.675\ngini = 0.206\nsamples = 103\nvalue = [91, 12]'),
#  Text(0.04583168708020545, 0.74, 'OnlineBackup_No <= 0.5\ngini = 0.157\nsamples = 93\nvalue = [85, 8]'),
#  Text(0.04319768207559594, 0.7, 'MultipleLines_No <= 0.5\ngini = 0.091\nsamples = 63\nvalue = [60, 3]'),
#  Text(0.04214408007375214, 0.66, 'StreamingTV_No <= 0.5\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.03898327406822073, 0.62, 'tenure <= 55.0\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.03792967206637693, 0.58, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.040036876070064537, 0.58, 'Partner <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.03898327406822073, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04109047807190833, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.04530488607928355, 0.62, 'MultipleLines_No phone service <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.044251284077439744, 0.58, 'Dependents <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.04319768207559594, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04530488607928355, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04635848808112735, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044251284077439744, 0.66, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(0.04846569208481496, 0.7, 'TotalCharges <= 747.85\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.047412090082971155, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04951929408665876, 0.66, 'TotalCharges <= 2707.9\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.04846569208481496, 0.62, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.050572896088502566, 0.62, 'tenure <= 37.0\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.04846569208481496, 0.58, 'tenure <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.047412090082971155, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04951929408665876, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05268010009219017, 0.58, 'MonthlyCharges <= 62.4\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.05162649809034637, 0.54, 'TotalCharges <= 3132.725\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.050572896088502566, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05268010009219017, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.053733702094033976, 0.54, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.05162649809034637, 0.74, 'TechSupport_No <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.050572896088502566, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.05268010009219017, 0.7, 'PaperlessBilling <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.05162649809034637, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.053733702094033976, 0.66, 'OnlineBackup_No <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05268010009219017, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05478730409587778, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06769392861846438, 0.82, 'TotalCharges <= 1166.325\ngini = 0.224\nsamples = 234\nvalue = [204, 30]'),
#  Text(0.059528513104174896, 0.78, 'TechSupport_No <= 0.5\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.055840906097721583, 0.74, 'TotalCharges <= 863.55\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.05478730409587778, 0.7, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.05689450809956539, 0.7, 'MultipleLines_Yes <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.055840906097721583, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05794811010140919, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06321612011062822, 0.74, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.0611089161069406, 0.7, 'Dependents <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.0600553141050968, 0.66, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.062162518108784405, 0.66, 'DeviceProtection_Yes <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0611089161069406, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06321612011062822, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06532332411431582, 0.7, 'TotalCharges <= 1126.825\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.06426972211247202, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.06637692611615963, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07585934413275386, 0.78, 'TotalCharges <= 2372.55\ngini = 0.196\nsamples = 209\nvalue = [186, 23]'),
#  Text(0.06848413011984723, 0.74, 'MonthlyCharges <= 81.85\ngini = 0.067\nsamples = 58\nvalue = [56, 2]'),
#  Text(0.06743052811800343, 0.7, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.06953773212169104, 0.7, 'MonthlyCharges <= 82.425\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.06848413011984723, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07059133412353484, 0.66, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.06953773212169104, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07164493612537864, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08323455814566047, 0.74, 'TotalCharges <= 2414.75\ngini = 0.239\nsamples = 151\nvalue = [130, 21]'),
#  Text(0.08218095614381667, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08428816014750427, 0.7, 'TotalCharges <= 3280.725\ngini = 0.223\nsamples = 149\nvalue = [130, 19]'),
#  Text(0.07849334913736336, 0.66, 'TotalCharges <= 2980.5\ngini = 0.32\nsamples = 60\nvalue = [48, 12]'),
#  Text(0.07375214012906625, 0.62, 'OnlineBackup_No <= 0.5\ngini = 0.219\nsamples = 40\nvalue = [35, 5]'),
#  Text(0.07164493612537864, 0.58, 'TotalCharges <= 2610.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.07059133412353484, 0.54, 'TotalCharges <= 2521.175\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.06953773212169104, 0.5, 'DeviceProtection_Yes <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.06848413011984723, 0.46, 'TotalCharges <= 2505.175\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06743052811800343, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06953773212169104, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07059133412353484, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07164493612537864, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07269853812722245, 0.54, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.07585934413275386, 0.58, 'SeniorCitizen <= 0.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.07480574213091006, 0.54, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.07691294613459766, 0.54, 'OnlineSecurity_Yes <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07585934413275386, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07796654813644147, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08323455814566047, 0.62, 'MonthlyCharges <= 80.425\ngini = 0.455\nsamples = 20\nvalue = [13, 7]'),
#  Text(0.08218095614381667, 0.58, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08112735414197288, 0.54, 'tenure <= 42.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.08007375214012907, 0.5, 'TotalCharges <= 3185.3\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.07902015013828527, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08112735414197288, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08218095614381667, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.08323455814566047, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08428816014750427, 0.58, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.0900829711576452, 0.66, 'TotalCharges <= 5279.225\ngini = 0.145\nsamples = 89\nvalue = [82, 7]'),
#  Text(0.08744896615303568, 0.62, 'TotalCharges <= 4027.775\ngini = 0.098\nsamples = 77\nvalue = [73, 4]'),
#  Text(0.08639536415119188, 0.58, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.08850256815487949, 0.58, 'TotalCharges <= 4065.15\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(0.08639536415119188, 0.54, 'tenure <= 49.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08534176214934808, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08744896615303568, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0906097721585671, 0.54, 'PaperlessBilling <= 0.5\ngini = 0.1\nsamples = 38\nvalue = [36, 2]'),
#  Text(0.08955617015672329, 0.5, 'SeniorCitizen <= 0.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.08850256815487949, 0.46, 'MonthlyCharges <= 73.275\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.08744896615303568, 0.42, 'MonthlyCharges <= 71.925\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.08639536415119188, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08850256815487949, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08955617015672329, 0.42, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.0906097721585671, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0916633741604109, 0.5, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.0927169761622547, 0.62, 'MonthlyCharges <= 77.075\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.0916633741604109, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0937705781640985, 0.58, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.0927169761622547, 0.54, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.09482418016594231, 0.54, 'PaperlessBilling <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.0937705781640985, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09587778216778611, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1300539971025945, 0.86, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.027\nsamples = 1041\nvalue = [1027, 14]'),
#  Text(0.12313973396549453, 0.82, 'SeniorCitizen <= 0.5\ngini = 0.021\nsamples = 965\nvalue = [955, 10]'),
#  Text(0.11774002370604504, 0.78, 'tenure <= 59.5\ngini = 0.016\nsamples = 896\nvalue = [889, 7]'),
#  Text(0.11326221519820888, 0.74, 'tenure <= 58.5\ngini = 0.028\nsamples = 428\nvalue = [422, 6]'),
#  Text(0.10746740418806795, 0.7, 'MultipleLines_Yes <= 0.5\ngini = 0.024\nsamples = 417\nvalue = [412, 5]'),
#  Text(0.10114579217700513, 0.66, 'OnlineSecurity_No <= 0.5\ngini = 0.013\nsamples = 304\nvalue = [302, 2]'),
#  Text(0.09903858817331752, 0.62, 'tenure <= 52.5\ngini = 0.007\nsamples = 276\nvalue = [275, 1]'),
#  Text(0.09798498617147372, 0.58, 'gini = 0.0\nsamples = 228\nvalue = [228, 0]'),
#  Text(0.10009219017516133, 0.58, 'tenure <= 53.5\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.09903858817331752, 0.54, 'PaymentMethod_Mailed check <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.09798498617147372, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10009219017516133, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.10114579217700513, 0.54, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(0.10325299618069274, 0.62, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.10219939417884893, 0.58, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.10430659818253654, 0.58, 'StreamingTV_No <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.10325299618069274, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.10536020018438035, 0.54, 'StreamingMovies_No <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10430659818253654, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10641380218622415, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11378901619913077, 0.66, 'MonthlyCharges <= 25.175\ngini = 0.052\nsamples = 113\nvalue = [110, 3]'),
#  Text(0.11273541419728697, 0.62, 'MonthlyCharges <= 25.125\ngini = 0.139\nsamples = 40\nvalue = [37, 3]'),
#  Text(0.11062821019359936, 0.58, 'TotalCharges <= 764.925\ngini = 0.102\nsamples = 37\nvalue = [35, 2]'),
#  Text(0.10957460819175556, 0.54, 'TotalCharges <= 658.875\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.10852100618991176, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.11062821019359936, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11168181219544317, 0.54, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.11484261820097458, 0.58, 'PaperlessBilling <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11378901619913077, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11589622020281838, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11484261820097458, 0.62, 'gini = 0.0\nsamples = 73\nvalue = [73, 0]'),
#  Text(0.11905702620834979, 0.7, 'TotalCharges <= 1123.725\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.11800342420650599, 0.66, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11694982220466218, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11905702620834979, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1201106282101936, 0.66, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.1222178322138812, 0.74, 'OnlineBackup_No <= 0.5\ngini = 0.004\nsamples = 468\nvalue = [467, 1]'),
#  Text(0.1211642302120374, 0.7, 'gini = 0.0\nsamples = 393\nvalue = [393, 0]'),
#  Text(0.123271434215725, 0.7, 'StreamingMovies_No <= 0.5\ngini = 0.026\nsamples = 75\nvalue = [74, 1]'),
#  Text(0.1222178322138812, 0.66, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.12432503621756881, 0.66, 'MonthlyCharges <= 65.9\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.123271434215725, 0.62, 'MonthlyCharges <= 63.35\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.1222178322138812, 0.58, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12432503621756881, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1253786382194126, 0.62, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.12853944422494404, 0.78, 'Dependents <= 0.5\ngini = 0.083\nsamples = 69\nvalue = [66, 3]'),
#  Text(0.12643224022125643, 0.74, 'DeviceProtection_No <= 0.5\ngini = 0.032\nsamples = 61\nvalue = [60, 1]'),
#  Text(0.1253786382194126, 0.7, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.12748584222310022, 0.7, 'MultipleLines_No <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.12643224022125643, 0.66, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.12853944422494404, 0.66, 'InternetService_Fiber optic <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12748584222310022, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12959304622678783, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13064664822863165, 0.74, 'PaperlessBilling <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.12959304622678783, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13170025023047544, 0.7, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.13696826023969447, 0.82, 'MultipleLines_No phone service <= 0.5\ngini = 0.1\nsamples = 76\nvalue = [72, 4]'),
#  Text(0.13380745423416304, 0.78, 'OnlineBackup_No <= 0.5\ngini = 0.033\nsamples = 59\nvalue = [58, 1]'),
#  Text(0.13275385223231925, 0.74, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(0.13486105623600686, 0.74, 'TotalCharges <= 5262.3\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.13380745423416304, 0.7, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.13591465823785065, 0.7, 'tenure <= 69.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13486105623600686, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13696826023969447, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14012906624522586, 0.78, 'Dependents <= 0.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.13907546424338207, 0.74, 'MonthlyCharges <= 47.45\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.13802186224153826, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.14012906624522586, 0.7, 'OnlineSecurity_No <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.13907546424338207, 0.66, 'TotalCharges <= 3192.275\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13802186224153826, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14012906624522586, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14118266824706968, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14118266824706968, 0.74, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2088313249045173, 0.9, 'Contract_Two year <= 0.5\ngini = 0.255\nsamples = 634\nvalue = [539, 95]'),
#  Text(0.1871213617805874, 0.86, 'TotalCharges <= 7961.05\ngini = 0.341\nsamples = 317\nvalue = [248, 69]'),
#  Text(0.17807520084288161, 0.82, 'tenure <= 70.5\ngini = 0.331\nsamples = 311\nvalue = [246, 65]'),
#  Text(0.1770215988410378, 0.78, 'Dependents <= 0.5\ngini = 0.348\nsamples = 290\nvalue = [225, 65]'),
#  Text(0.15998287896747004, 0.74, 'MonthlyCharges <= 103.2\ngini = 0.382\nsamples = 214\nvalue = [159, 55]'),
#  Text(0.14434347425260108, 0.7, 'tenure <= 14.5\ngini = 0.288\nsamples = 103\nvalue = [85, 18]'),
#  Text(0.1432898722507573, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1453970762544449, 0.66, 'TotalCharges <= 6592.4\ngini = 0.278\nsamples = 102\nvalue = [85, 17]'),
#  Text(0.14434347425260108, 0.62, 'tenure <= 66.5\ngini = 0.309\nsamples = 89\nvalue = [72, 17]'),
#  Text(0.1432898722507573, 0.58, 'tenure <= 32.0\ngini = 0.298\nsamples = 88\nvalue = [72, 16]'),
#  Text(0.14223627024891347, 0.54, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.14434347425260108, 0.54, 'tenure <= 37.5\ngini = 0.323\nsamples = 79\nvalue = [63, 16]'),
#  Text(0.14164361912287635, 0.5, 'Partner <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.14059001712103253, 0.46, 'TotalCharges <= 3579.05\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13953641511918874, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14164361912287635, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14269722112472014, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14704332938232584, 0.5, 'StreamingTV_Yes <= 0.5\ngini = 0.29\nsamples = 74\nvalue = [61, 13]'),
#  Text(0.14598972738048202, 0.46, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.14809693138416963, 0.46, 'MonthlyCharges <= 100.325\ngini = 0.331\nsamples = 62\nvalue = [49, 13]'),
#  Text(0.14375082312656395, 0.42, 'MonthlyCharges <= 99.45\ngini = 0.386\nsamples = 46\nvalue = [34, 12]'),
#  Text(0.13927301461872776, 0.38, 'MonthlyCharges <= 96.825\ngini = 0.313\nsamples = 36\nvalue = [29, 7]'),
#  Text(0.13663900961411826, 0.34, 'MultipleLines_No <= 0.5\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.13453180561043065, 0.3, 'MonthlyCharges <= 96.625\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.13347820360858687, 0.26, 'OnlineSecurity_No <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.13242460160674305, 0.22, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13137099960489926, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13347820360858687, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13453180561043065, 0.22, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.13558540761227447, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13874621361780587, 0.3, 'tenure <= 53.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.13769261161596208, 0.26, 'MonthlyCharges <= 94.125\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.13663900961411826, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13874621361780587, 0.22, 'MonthlyCharges <= 95.6\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.13769261161596208, 0.18, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1397998156196497, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1397998156196497, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1419070196233373, 0.34, 'TotalCharges <= 5483.575\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.14085341762149348, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.14296062162518108, 0.3, 'tenure <= 57.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1419070196233373, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1440142236270249, 0.26, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.14822863163440012, 0.38, 'TotalCharges <= 5459.525\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.1461214276307125, 0.34, 'TotalCharges <= 4347.75\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1450678256288687, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1471750296325563, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.15033583563808772, 0.34, 'MonthlyCharges <= 99.75\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1492822336362439, 0.3, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14822863163440012, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15033583563808772, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1513894376399315, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15244303964177533, 0.42, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.1513894376399315, 0.38, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.15349664164361912, 0.38, 'OnlineBackup_No <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.15244303964177533, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15455024364546294, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1453970762544449, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14645067825628869, 0.62, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.175622283682339, 0.7, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.444\nsamples = 111\nvalue = [74, 37]'),
#  Text(0.16877387067035426, 0.66, 'MultipleLines_No <= 0.5\ngini = 0.382\nsamples = 74\nvalue = [55, 19]'),
#  Text(0.16561306466482287, 0.62, 'MonthlyCharges <= 103.275\ngini = 0.316\nsamples = 61\nvalue = [49, 12]'),
#  Text(0.16455946266297905, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16666666666666666, 0.58, 'MonthlyCharges <= 117.475\ngini = 0.299\nsamples = 60\nvalue = [49, 11]'),
#  Text(0.16561306466482287, 0.54, 'MonthlyCharges <= 111.525\ngini = 0.282\nsamples = 59\nvalue = [49, 10]'),
#  Text(0.16455946266297905, 0.5, 'MonthlyCharges <= 110.7\ngini = 0.33\nsamples = 48\nvalue = [38, 10]'),
#  Text(0.16350586066113526, 0.46, 'MonthlyCharges <= 106.375\ngini = 0.263\nsamples = 45\nvalue = [38, 7]'),
#  Text(0.15981825365468194, 0.42, 'MonthlyCharges <= 105.6\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.15771104965099433, 0.38, 'tenure <= 53.0\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.15665744764915054, 0.34, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.15876465165283815, 0.34, 'tenure <= 58.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.15771104965099433, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15981825365468194, 0.3, 'TotalCharges <= 7207.85\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.15876465165283815, 0.26, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.16087185565652576, 0.26, 'MonthlyCharges <= 104.95\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15981825365468194, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16192545765836955, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16192545765836955, 0.38, 'tenure <= 44.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.16087185565652576, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16297905966021337, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16719346766758858, 0.42, 'TotalCharges <= 4845.3\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.16613986566574476, 0.38, 'OnlineBackup_No <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16508626366390097, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16719346766758858, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16824706966943237, 0.38, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.16561306466482287, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16666666666666666, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.16772026866851047, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1719346766758857, 0.62, 'TotalCharges <= 7256.95\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.17088107467404187, 0.58, 'MonthlyCharges <= 104.625\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.16982747267219808, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1719346766758857, 0.54, 'MonthlyCharges <= 105.55\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.17088107467404187, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17298827867772948, 0.5, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1719346766758857, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1740418806795733, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17298827867772948, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18247069669432373, 0.66, 'OnlineSecurity_No <= 0.5\ngini = 0.5\nsamples = 37\nvalue = [19, 18]'),
#  Text(0.18036349269063612, 0.62, 'tenure <= 60.0\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.1793098906887923, 0.58, 'MonthlyCharges <= 110.325\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.1782562886869485, 0.54, 'tenure <= 42.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.1772026866851047, 0.5, 'OnlineBackup_No <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1761490846832609, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1782562886869485, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1793098906887923, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.18036349269063612, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1814170946924799, 0.58, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.18457790069801133, 0.62, 'OnlineBackup_Yes <= 0.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.18352429869616751, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.18563150269985512, 0.58, 'TotalCharges <= 6867.175\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.18352429869616751, 0.54, 'SeniorCitizen <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.18247069669432373, 0.5, 'TotalCharges <= 5903.775\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.1814170946924799, 0.46, 'MonthlyCharges <= 110.925\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.18036349269063612, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18247069669432373, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18352429869616751, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.18457790069801133, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18773870670354273, 0.54, 'SeniorCitizen <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.18668510470169894, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.18879230870538655, 0.5, 'TotalCharges <= 7400.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18773870670354273, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18984591070723034, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19406031871460555, 0.74, 'OnlineBackup_Yes <= 0.5\ngini = 0.229\nsamples = 76\nvalue = [66, 10]'),
#  Text(0.18984591070723034, 0.7, 'Partner <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.18879230870538655, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19089951270907415, 0.66, 'MonthlyCharges <= 94.875\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.18879230870538655, 0.62, 'SeniorCitizen <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.18773870670354273, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18984591070723034, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19300671671276176, 0.62, 'MonthlyCharges <= 102.25\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.19195311471091794, 0.58, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.19406031871460555, 0.58, 'TotalCharges <= 5899.75\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.19300671671276176, 0.54, 'MultipleLines_No <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.19195311471091794, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.19406031871460555, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19511392071644937, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19827472672198077, 0.7, 'tenure <= 23.5\ngini = 0.109\nsamples = 52\nvalue = [49, 3]'),
#  Text(0.19722112472013698, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19932832872382458, 0.66, 'MonthlyCharges <= 111.7\ngini = 0.075\nsamples = 51\nvalue = [49, 2]'),
#  Text(0.19722112472013698, 0.62, 'tenure <= 65.5\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.19616752271829316, 0.58, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.19827472672198077, 0.58, 'TotalCharges <= 6692.825\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.19722112472013698, 0.54, 'PaperlessBilling <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19616752271829316, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19827472672198077, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19932832872382458, 0.54, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.2014355327275122, 0.62, 'MonthlyCharges <= 112.15\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.20038193072566837, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20248913472935598, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1791288028447254, 0.78, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.19616752271829316, 0.82, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.19511392071644937, 0.78, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.19722112472013698, 0.78, 'MonthlyCharges <= 117.05\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.19616752271829316, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19827472672198077, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23054128802844726, 0.86, 'MonthlyCharges <= 94.075\ngini = 0.151\nsamples = 317\nvalue = [291, 26]'),
#  Text(0.22843408402475965, 0.82, 'TotalCharges <= 6102.3\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.22738048202291583, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22948768602660344, 0.78, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23264849203213486, 0.82, 'TotalCharges <= 7755.6\ngini = 0.141\nsamples = 314\nvalue = [290, 24]'),
#  Text(0.23159489003029105, 0.78, 'TotalCharges <= 7689.875\ngini = 0.194\nsamples = 221\nvalue = [197, 24]'),
#  Text(0.2206637692611616, 0.74, 'MonthlyCharges <= 105.95\ngini = 0.166\nsamples = 208\nvalue = [189, 19]'),
#  Text(0.2093375477413407, 0.7, 'TotalCharges <= 5514.15\ngini = 0.099\nsamples = 134\nvalue = [127, 7]'),
#  Text(0.2067035427367312, 0.66, 'TotalCharges <= 5444.45\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.2056499407348874, 0.62, 'TotalCharges <= 4550.65\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.2045963387330436, 0.58, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.2067035427367312, 0.58, 'tenure <= 44.0\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.2056499407348874, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.207757144738575, 0.54, 'StreamingMovies_Yes <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.2067035427367312, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2088107467404188, 0.5, 'MonthlyCharges <= 96.725\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.207757144738575, 0.46, 'Dependents <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2067035427367312, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2088107467404188, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20986434874226262, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.207757144738575, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21197155274595023, 0.66, 'tenure <= 69.5\ngini = 0.056\nsamples = 105\nvalue = [102, 3]'),
#  Text(0.2109179507441064, 0.62, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.21302515474779402, 0.62, 'tenure <= 70.5\ngini = 0.107\nsamples = 53\nvalue = [50, 3]'),
#  Text(0.2109179507441064, 0.58, 'DeviceProtection_No <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.20986434874226262, 0.54, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.21197155274595023, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21513235875148162, 0.58, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.044\nsamples = 44\nvalue = [43, 1]'),
#  Text(0.21407875674963783, 0.54, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.21618596075332544, 0.54, 'OnlineSecurity_No <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.21513235875148162, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.21723956275516923, 0.5, 'Dependents <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.21618596075332544, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.21829316475701305, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23198999078098248, 0.7, 'MonthlyCharges <= 110.025\ngini = 0.272\nsamples = 74\nvalue = [62, 12]'),
#  Text(0.22672198077176348, 0.66, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.375\nsamples = 44\nvalue = [33, 11]'),
#  Text(0.22145397076254444, 0.62, 'OnlineBackup_No <= 0.5\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(0.21934676675885684, 0.58, 'MonthlyCharges <= 109.425\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.21829316475701305, 0.54, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.22040036876070065, 0.54, 'DeviceProtection_No <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21934676675885684, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22145397076254444, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22356117476623205, 0.58, 'MonthlyCharges <= 106.65\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.22250757276438826, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.22461477676807587, 0.54, 'tenure <= 69.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.22356117476623205, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.22566837876991966, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23198999078098248, 0.62, 'tenure <= 70.0\ngini = 0.484\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.2309363887791387, 0.58, 'tenure <= 68.5\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.22988278677729487, 0.54, 'TotalCharges <= 6406.45\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.22777558277360727, 0.5, 'TotalCharges <= 5096.925\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.22672198077176348, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22882918477545108, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.23198999078098248, 0.5, 'TotalCharges <= 7560.2\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.2309363887791387, 0.46, 'PaperlessBilling <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.22988278677729487, 0.42, 'tenure <= 65.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.22882918477545108, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2309363887791387, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23198999078098248, 0.42, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2330435927828263, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23198999078098248, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2330435927828263, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2372580007902015, 0.66, 'OnlineBackup_Yes <= 0.5\ngini = 0.064\nsamples = 30\nvalue = [29, 1]'),
#  Text(0.2362043987883577, 0.62, 'tenure <= 62.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2351507967865139, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2372580007902015, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2383116027920453, 0.62, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.24252601079942052, 0.74, 'TotalCharges <= 7699.3\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.24147240879757673, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24357961280126433, 0.7, 'MonthlyCharges <= 112.675\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.24147240879757673, 0.66, 'TechSupport_No <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.2404188067957329, 0.62, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.24252601079942052, 0.62, 'TotalCharges <= 7730.625\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24147240879757673, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24357961280126433, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24568681680495194, 0.66, 'TotalCharges <= 7717.575\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.24463321480310812, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24674041880679573, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23370209403397865, 0.78, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]'),
#  Text(0.5908680281180034, 0.94, 'InternetService_Fiber optic <= 0.5\ngini = 0.49\nsamples = 3085\nvalue = [1756, 1329]'),
#  Text(0.42396111138548664, 0.9, 'tenure <= 5.5\ngini = 0.407\nsamples = 1390\nvalue = [994, 396]'),
#  Text(0.3461113443303042, 0.86, 'TechSupport_No <= 0.5\ngini = 0.487\nsamples = 588\nvalue = [341, 247]'),
#  Text(0.27957493744238116, 0.82, 'tenure <= 1.5\ngini = 0.409\nsamples = 286\nvalue = [204, 82]'),
#  Text(0.26038785723692875, 0.78, 'SeniorCitizen <= 0.5\ngini = 0.467\nsamples = 140\nvalue = [88, 52]'),
#  Text(0.25933425523508497, 0.74, 'PaperlessBilling <= 0.5\ngini = 0.457\nsamples = 136\nvalue = [88, 48]'),
#  Text(0.2505268010009219, 0.7, 'MonthlyCharges <= 19.225\ngini = 0.417\nsamples = 91\nvalue = [64, 27]'),
#  Text(0.2494731989990781, 0.66, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2515804030027657, 0.66, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.439\nsamples = 83\nvalue = [56, 27]'),
#  Text(0.2505268010009219, 0.62, 'MonthlyCharges <= 19.475\ngini = 0.458\nsamples = 76\nvalue = [49, 27]'),
#  Text(0.24568681680495194, 0.58, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.24463321480310812, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24674041880679573, 0.54, 'Partner <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24568681680495194, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24779402080863955, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2553667851968919, 0.58, 'MonthlyCharges <= 57.575\ngini = 0.444\nsamples = 72\nvalue = [48, 24]'),
#  Text(0.2543131831950481, 0.54, 'Partner <= 0.5\ngini = 0.438\nsamples = 71\nvalue = [48, 23]'),
#  Text(0.24990122481232716, 0.5, 'MonthlyCharges <= 20.175\ngini = 0.417\nsamples = 64\nvalue = [45, 19]'),
#  Text(0.2452917160542605, 0.46, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.475\nsamples = 31\nvalue = [19, 12]'),
#  Text(0.2442381140524167, 0.42, 'TotalCharges <= 20.075\ngini = 0.464\nsamples = 30\nvalue = [19, 11]'),
#  Text(0.24134070854734624, 0.38, 'TotalCharges <= 19.8\ngini = 0.444\nsamples = 27\nvalue = [18, 9]'),
#  Text(0.23870670354273674, 0.34, 'PaymentMethod_Bank transfer (automatic) <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.23765310154089292, 0.3, 'MonthlyCharges <= 19.675\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.23659949953904913, 0.26, 'Dependents <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.2355458975372053, 0.22, 'TotalCharges <= 19.6\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.23449229553536152, 0.18, 'MonthlyCharges <= 19.525\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2334386935335177, 0.14, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2355458975372053, 0.14, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.23659949953904913, 0.18, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.23765310154089292, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23870670354273674, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23976030554458053, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.24397471355195574, 0.34, 'PaymentMethod_Mailed check <= 0.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.24186750954826813, 0.3, 'TotalCharges <= 19.975\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24081390754642434, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24292111155011195, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24608191755564335, 0.3, 'MonthlyCharges <= 20.025\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
# ...
#  Text(0.3817990254181483, 0.26, 'TotalCharges <= 82.7\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.3807454234163045, 0.22, 'MonthlyCharges <= 45.625\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3796918214144607, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3817990254181483, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3828526274199921, 0.22, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3828526274199921, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3839062294218359, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3870670354273673, 0.38, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3860134334255235, 0.34, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3881206374292111, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3923350454365863, 0.46, 'TotalCharges <= 53.925\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.3912814434347425, 0.42, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3933886474384301, 0.42, 'MultipleLines_Yes <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.3912814434347425, 0.38, 'MonthlyCharges <= 54.825\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.39022784143289874, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3923350454365863, 0.34, 'TotalCharges <= 55.25\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3912814434347425, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3933886474384301, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39549585144211774, 0.38, 'TotalCharges <= 54.325\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.39444224944027395, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39654945344396153, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.39865665744764917, 0.5, 'TotalCharges <= 207.525\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.3976030554458053, 0.46, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.39654945344396153, 0.42, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.39865665744764917, 0.42, 'tenure <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3976030554458053, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.39971025944949296, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39971025944949296, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4076122744633215, 0.58, 'MonthlyCharges <= 53.7\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.40497826945871196, 0.54, 'MonthlyCharges <= 49.475\ngini = 0.401\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.4028710654550244, 0.5, 'TotalCharges <= 48.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.40181746345318053, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.40392466745686817, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4070854734623996, 0.5, 'Dependents <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.40603187146055575, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4081390754642434, 0.46, 'TotalCharges <= 50.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4070854734623996, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4091926774660872, 0.42, 'MonthlyCharges <= 50.9\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4081390754642434, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41024627946793096, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41024627946793096, 0.54, 'TotalCharges <= 135.55\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4091926774660872, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4112998814697748, 0.5, 'TotalCharges <= 161.375\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.41024627946793096, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4123534834716186, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4123534834716186, 0.7, 'TotalCharges <= 60.65\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.4112998814697748, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4134070854734624, 0.66, 'MonthlyCharges <= 61.625\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.4123534834716186, 0.62, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.4144606874753062, 0.62, 'DeviceProtection_Yes <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.4134070854734624, 0.58, 'TotalCharges <= 115.7\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4123534834716186, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4144606874753062, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.41551428947715, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4218359014882128, 0.74, 'MonthlyCharges <= 67.125\ngini = 0.365\nsamples = 25\nvalue = [19, 6]'),
#  Text(0.420782299486369, 0.7, 'MultipleLines_No <= 0.5\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.41972869748452524, 0.66, 'MonthlyCharges <= 52.4\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.4186750954826814, 0.62, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4176214934808376, 0.58, 'TotalCharges <= 218.85\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4165678914789938, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4186750954826814, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.41972869748452524, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.420782299486369, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4218359014882128, 0.66, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.4228895034900566, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42499670749374424, 0.78, 'TotalCharges <= 45.175\ngini = 0.326\nsamples = 39\nvalue = [8, 31]'),
#  Text(0.42394310549190045, 0.74, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.42605030949558803, 0.74, 'TotalCharges <= 45.925\ngini = 0.417\nsamples = 27\nvalue = [8, 19]'),
#  Text(0.42499670749374424, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4271039114974318, 0.7, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.42605030949558803, 0.66, 'TotalCharges <= 90.2\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.42394310549190045, 0.62, 'TotalCharges <= 80.3\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.4228895034900566, 0.58, 'TotalCharges <= 46.9\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4218359014882128, 0.54, 'TotalCharges <= 46.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.420782299486369, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4228895034900566, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42394310549190045, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.42499670749374424, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.42815751349927567, 0.62, 'DeviceProtection_No <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.4271039114974318, 0.58, 'PaymentMethod_Mailed check <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.42605030949558803, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42815751349927567, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42921111550111946, 0.58, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.42815751349927567, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5018108784406691, 0.86, 'PhoneService <= 0.5\ngini = 0.303\nsamples = 802\nvalue = [653, 149]'),
#  Text(0.4676675885684183, 0.82, 'Dependents <= 0.5\ngini = 0.416\nsamples = 193\nvalue = [136, 57]'),
#  Text(0.45291716054260506, 0.78, 'PaymentMethod_Electronic check <= 0.5\ngini = 0.446\nsamples = 146\nvalue = [97, 49]'),
#  Text(0.4460687475306203, 0.74, 'tenure <= 47.5\ngini = 0.358\nsamples = 77\nvalue = [59, 18]'),
#  Text(0.4439615435269327, 0.7, 'TotalCharges <= 1990.8\ngini = 0.402\nsamples = 61\nvalue = [44, 17]'),
#  Text(0.4429079415250889, 0.66, 'tenure <= 44.5\ngini = 0.379\nsamples = 59\nvalue = [44, 15]'),
#  Text(0.4418543395232451, 0.62, 'PaymentMethod_Credit card (automatic) <= 0.5\ngini = 0.366\nsamples = 58\nvalue = [44, 14]'),
#  Text(0.43395232450941656, 0.58, 'StreamingTV_No <= 0.5\ngini = 0.272\nsamples = 37\nvalue = [31, 6]'),
#  Text(0.43026471750296325, 0.54, 'tenure <= 10.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.42921111550111946, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.43131831950480704, 0.5, 'MonthlyCharges <= 39.575\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.43026471750296325, 0.46, 'PaperlessBilling <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.42921111550111946, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43131831950480704, 0.42, 'tenure <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.43026471750296325, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4323719215066509, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4323719215066509, 0.46, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4376399315158699, 0.54, 'StreamingMovies_No <= 0.5\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.43553272751218225, 0.5, 'PaperlessBilling <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.43447912551033846, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4365863295140261, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.43974713551955746, 0.5, 'TotalCharges <= 255.925\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.4386935335177137, 0.46, 'DeviceProtection_Yes <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4376399315158699, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.43974713551955746, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4408007375214013, 0.46, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.44975635453707363, 0.58, 'TotalCharges <= 1035.35\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.4460687475306203, 0.54, 'TotalCharges <= 587.075\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.4439615435269327, 0.5, 'TotalCharges <= 296.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4429079415250889, 0.46, 'MonthlyCharges <= 32.675\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4418543395232451, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4439615435269327, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4450151455287765, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4481759515343079, 0.5, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.4471223495324641, 0.46, 'Partner <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4460687475306203, 0.42, 'TotalCharges <= 761.85\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4450151455287765, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4471223495324641, 0.38, 'TotalCharges <= 892.2\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4460687475306203, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4481759515343079, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4481759515343079, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44922955353615174, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.45344396154352695, 0.54, 'tenure <= 25.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4523903595416831, 0.5, 'StreamingMovies_No <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4513367575398393, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45344396154352695, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45449756354537074, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4439615435269327, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4450151455287765, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4481759515343079, 0.7, 'tenure <= 58.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.4471223495324641, 0.66, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.44922955353615174, 0.66, 'DeviceProtection_No <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4481759515343079, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4502831555379955, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45976557355458975, 0.74, 'PaperlessBilling <= 0.5\ngini = 0.495\nsamples = 69\nvalue = [38, 31]'),
#  Text(0.45449756354537074, 0.7, 'OnlineSecurity_Yes <= 0.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.45344396154352695, 0.66, 'MonthlyCharges <= 45.825\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.4523903595416831, 0.62, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.45449756354537074, 0.62, 'Partner <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.45344396154352695, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.45555116554721453, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45555116554721453, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.46503358356380875, 0.7, 'TotalCharges <= 906.05\ngini = 0.497\nsamples = 54\nvalue = [25, 29]'),
#  Text(0.46081917555643354, 0.66, 'Partner <= 0.5\ngini = 0.393\nsamples = 26\nvalue = [7, 19]'),
#  Text(0.45976557355458975, 0.62, 'MonthlyCharges <= 31.35\ngini = 0.455\nsamples = 20\nvalue = [7, 13]'),
#  Text(0.45765836955090217, 0.58, 'MonthlyCharges <= 27.175\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.4566047675490583, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45871197155274596, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4618727775582774, 0.58, 'OnlineBackup_Yes <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.46081917555643354, 0.54, 'tenure <= 13.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.45871197155274596, 0.5, 'TotalCharges <= 284.075\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.45765836955090217, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45976557355458975, 0.46, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.46292637956012117, 0.5, 'TechSupport_Yes <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4618727775582774, 0.46, 'TotalCharges <= 692.725\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.46081917555643354, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.46292637956012117, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.46397998156196496, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.46292637956012117, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4618727775582774, 0.62, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.46924799157118396, 0.66, 'tenure <= 38.5\ngini = 0.459\nsamples = 28\nvalue = [18, 10]'),
#  Text(0.4671407875674964, 0.62, 'MonthlyCharges <= 42.625\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.4660871855656526, 0.58, 'MonthlyCharges <= 40.075\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.46503358356380875, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4671407875674964, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4681943895693402, 0.58, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4713551955748716, 0.62, 'tenure <= 40.5\ngini = 0.499\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.4703015935730278, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4724087975767154, 0.58, 'MonthlyCharges <= 39.6\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.4713551955748716, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4734623995785592, 0.54, 'tenure <= 52.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.4724087975767154, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.474516001580403, 0.5, 'TotalCharges <= 2658.975\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.4734623995785592, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4755696035822468, 0.46, 'tenure <= 55.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  ...]

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree= plot_tree(model, feature_names=feature_list,
                filled=True,
                fontsize=10)

# %%
model.feature_importances_
# Out:
# array([0.02052351, 0.01654821, 0.01564359, 0.0902109 , 0.00279486,
#        0.02751127, 0.18006189, 0.24465134, 0.01001717, 0.00085309,
#        0.00916957, 0.        , 0.04995484, 0.        , 0.0133093 ,
#        0.        , 0.00962584, 0.01084303, 0.00095879, 0.00819908,
#        0.00793907, 0.        , 0.01038668, 0.01761317, 0.        ,
#        0.00577529, 0.00707745, 0.        , 0.00371535, 0.00691413,
#        0.        , 0.00700791, 0.17045483, 0.        , 0.00386284,
#        0.01092085, 0.01063012, 0.01856656, 0.00825946])

# %%
sns.barplot(x=model.feature_importances_, y=feature_list, palette="Set2")
# Out:
# <ipython-input-171-1e5c01d452cb>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=model.feature_importances_, y=feature_list, palette="Set2")
# <Axes: >

# %%
# diff_count= abs(y_test- y_predict).sum()
# diff_count
diff_count = sum(x != y for x, y in zip(y_test, y_predict))
print(diff_count)
# Out:
# 381

# %%
diff_count/len(y_test)
# Out:
# 0.27078891257995735

# %%
(len(y_test)-diff_count)/len(y_test)*100
# Out:
# 72.92110874200426

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.7292110874200426
